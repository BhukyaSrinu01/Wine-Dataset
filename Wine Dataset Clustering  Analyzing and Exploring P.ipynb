# %% [markdown]
# # Wine Dataset Clustering: Analyzing and Exploring P

# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data = r'C:\Users\Shiva\Downloads\FSDS---srinu\kaggle,linkedin\wine-clustering.csv'
df = pd.read_csv(data)
df.head()

#These attributes can provide valuable information for analyzing and understanding the characteristics of different wines.
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
df.nunique()
# Out:
# Alcohol                 126
# Malic_Acid              133
# Ash                      79
# Ash_Alcanity             63
# Magnesium                53
# Total_Phenols            97
# Flavanoids              132
# Nonflavanoid_Phenols     39
# Proanthocyanins         101
# Color_Intensity         132
# Hue                      78
# OD280                   122
# Proline                 121
# dtype: int64

# %%
#Calculate the number of missing values in each column of the "wine" dataset
df.isna().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,7))
corr = df.corr()
sns.heatmap(corr, vmin=-1, center = 0, vmax = 1, annot = True);

# %%
from sklearn.preprocessing import StandardScaler, Normalizer
scaler = StandardScaler()
#scaler = Normalizer()
wine_scaled = scaler.fit_transform(df)

# %%
#figure size

from sklearn.decomposition import PCA
pca = PCA(n_components=2)
plt.figure(figsize=(8,6))
X_pca = pca.fit_transform(wine_scaled)
principal_df = pd.DataFrame(data = X_pca, columns = ['PC1', 'PC2'])

#scatterPlot
plt.scatter(principal_df.iloc[:,0], principal_df.iloc[:,1], s=40)


#Aesthetics
plt.title('PCA plot in 2D')
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# Text(0, 0.5, 'PC2')

# %%
#PCA

from sklearn.decomposition import PCA
pca =PCA(n_components=2)

#convert to data frame
principal_df = pd.DataFrame(data = X_pca, columns = ['PC1', 'PC2'])

#Shape and Preview
print(principal_df.shape)
principal_df.head()
# Out:
# (178, 2)
#         PC1       PC2
# 0  3.316751 -1.443463
# 1  2.209465  0.333393
# 2  2.516740 -1.031151
# 3  3.757066 -2.756372
# 4  1.008908 -0.869831
